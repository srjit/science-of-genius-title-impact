# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import sys
sys.path.insert(0, "../../code-previous")

# %%
import pandas as pd
import numpy as np
import operator

import peakutils

import string
import nltk
stopwords = nltk.corpus.stopwords.words('english')

import operator


import pickle
from sklearn.feature_extraction.text import CountVectorizer

import plotly
import plotly.plotly as py
from plotly import tools

import plotly.graph_objs as go
plotly.tools.set_credentials_file(username='sreejith_s', api_key='rcet0rTqFCc3WeOzWTjv')

from unicodedata import category
from tqdm import tqdm
tqdm.pandas(desc="Progress")

import seaborn as sns
sns.set_style('white')
import matplotlib.pylab as plt

# %%
filename = "/mnt/disks/vault/analysis-data/interdisciplinary-novelty-analysis/corrected-entropy-analysis/word-journey-data.pql"
#data_grouped_by_year_label.to_pickle(filename)


data_grouped_by_year_label = pd.read_pickle(filename)

# %%
data_grouped_by_year_label.head()
# Out:
#    index      Label  PubYear  \
# 0      0  Acoustics     1929
# 1      1  Acoustics     1930
# 2      2  Acoustics     1931
# 3      3  Acoustics     1932
# 4      4  Acoustics     1933
#
#                              title_without_stopwords  \
# 0  [hearing speech auditoriums, hearing speech au...
# 1  [reverberation time bridge  instrumental metho...
# 2  [some physical characteristics speech music, s...
# 3  [position finding under water sound signals, p...
# 4  [some notes character bell tones, some notes c...
#
#                                       cleaned_titles  \
# 0  [psychological measurements annoyance related ...
# 1  [theory horn type loud speaker, discussion sym...
# 2  [microphone technique radio broadcasting, orga...
# 3  [acoustic pick up philadelphia orchestra broad...
# 4  [sound absorption non reactive mixtures, deter...
#
#                                         title_words_  \
# 0  psychological measurements annoyance related p...
# 1  theory horn type loud speaker discussion sympo...
# 2  microphone technique radio broadcasting organ ...
# 3  acoustic pick up philadelphia orchestra broadc...
# 4  sound absorption non reactive mixtures determi...
#
#                                          title_words
# 0  psychological measurements annoyance related p...
# 1  theory horn type loud speaker discussion sympo...
# 2  microphone technique radio broadcasting organ ...
# 3  acoustic pick up philadelphia orchestra broadc...
# 4  sound absorption non reactive mixtures determi...

# %%
tovector_input = pd.DataFrame(data_grouped_by_year_label[["Label", "title_words"]].groupby(data_grouped_by_year_label.Label)["title_words"].apply(list))
tovector_input["words"] = tovector_input["title_words"].progress_apply(lambda x: " ".join(x))
# Out:
# Progress: 100%|██████████| 249/249 [00:04<00:00, 61.67it/s]

# %%
len(tovector_input)
# Out:
# 249

# %%
tovector_input.head()
# Out:
#                                                                            title_words  \
# Label
# Acoustics                            [psychological measurements annoyance related ...
# Agricultural Economics & Policy      [methods maintaining fertility successful jers...
# Agricultural Engineering             [studies high temperature drying discoloration...
# Agriculture, Dairy & Animal Science  [propionic acid sodium propionate calcium prop...
# Agriculture, Multidisciplinary       [variation chemical composition mangels bearin...
#
#                                                                                  words
# Label
# Acoustics                            psychological measurements annoyance related p...
# Agricultural Economics & Policy      methods maintaining fertility successful jerse...
# Agricultural Engineering             studies high temperature drying discoloration ...
# Agriculture, Dairy & Animal Science  propionic acid sodium propionate calcium propi...
# Agriculture, Multidisciplinary       variation chemical composition mangels bearing...

# %%
vectorizer = CountVectorizer()
vectorized_words = vectorizer.fit_transform(tovector_input.words)

# %%
count_vocab = {value:key for key,value in vectorizer.vocabulary_.items()}
count_rev_dict = {value:key for key,value in vectorizer.vocabulary_.items()}
words = [count_rev_dict[i] for i in range(len(vectorizer.vocabulary_.keys()))]

# %%
vectorized_wordarray = vectorized_words.toarray()
document_frequency = (vectorized_wordarray != 0).sum(0).tolist()
document_frequency_log =  [np.log(x) for x in document_frequency]
#2. Term Frequency - Number of times in which a word appears in a document
term_frequency = vectorized_words.sum(axis=0).reshape(-1,).tolist()[0]
term_frequency_log = [np.log(x) for x in term_frequency]

# %%
vectorized_wordarray.shape
# Out:
# (249, 2034183)

# %%
data_grouped_by_year_label["number_of_pubs"] = data_grouped_by_year_label["title_without_stopwords"].progress_apply(lambda x: len(x))
# Out:
# Progress: 100%|██████████| 19980/19980 [00:00<00:00, 625893.96it/s]

# %%
data_grouped_by_year_label["word_count"] = data_grouped_by_year_label["title_words"].progress_apply(lambda x: len(x.split()))
# Out:
# Progress: 100%|██████████| 19980/19980 [00:52<00:00, 377.72it/s]

# %%
data_grouped_by_year_label.head()
# Out:
#    index      Label  PubYear  \
# 0      0  Acoustics     1929
# 1      1  Acoustics     1930
# 2      2  Acoustics     1931
# 3      3  Acoustics     1932
# 4      4  Acoustics     1933
#
#                              title_without_stopwords  \
# 0  [hearing speech auditoriums, hearing speech au...
# 1  [reverberation time bridge  instrumental metho...
# 2  [some physical characteristics speech music, s...
# 3  [position finding under water sound signals, p...
# 4  [some notes character bell tones, some notes c...
#
#                                       cleaned_titles  \
# 0  [psychological measurements annoyance related ...
# 1  [theory horn type loud speaker, discussion sym...
# 2  [microphone technique radio broadcasting, orga...
# 3  [acoustic pick up philadelphia orchestra broad...
# 4  [sound absorption non reactive mixtures, deter...
#
#                                         title_words_  \
# 0  psychological measurements annoyance related p...
# 1  theory horn type loud speaker discussion sympo...
# 2  microphone technique radio broadcasting organ ...
# 3  acoustic pick up philadelphia orchestra broadc...
# 4  sound absorption non reactive mixtures determi...
#
#                                          title_words  number_of_pubs  \
# 0  psychological measurements annoyance related p...              16
# 1  theory horn type loud speaker discussion sympo...             112
# 2  microphone technique radio broadcasting organ ...              66
# 3  acoustic pick up philadelphia orchestra broadc...              68
# 4  sound absorption non reactive mixtures determi...              62
#
#    word_count
# 0          40
# 1         250
# 2         178
# 3         159
# 4         164

# %%
data_grouped_by_year_label[data_grouped_by_year_label.Label == "Astronomy & Astrophysics"]
# Out:
#       index                     Label  PubYear  \
# 1212   1212  Astronomy & Astrophysics     1900
# 1213   1213  Astronomy & Astrophysics     1901
# 1214   1214  Astronomy & Astrophysics     1902
# 1215   1215  Astronomy & Astrophysics     1903
# 1216   1216  Astronomy & Astrophysics     1904
# 1217   1217  Astronomy & Astrophysics     1905
# 1218   1218  Astronomy & Astrophysics     1906
# 1219   1219  Astronomy & Astrophysics     1907
# 1220   1220  Astronomy & Astrophysics     1908
# 1221   1221  Astronomy & Astrophysics     1909
# 1222   1222  Astronomy & Astrophysics     1910
# 1223   1223  Astronomy & Astrophysics     1911
# 1224   1224  Astronomy & Astrophysics     1912
# 1225   1225  Astronomy & Astrophysics     1913
# 1226   1226  Astronomy & Astrophysics     1914
# 1227   1227  Astronomy & Astrophysics     1915
# 1228   1228  Astronomy & Astrophysics     1916
# 1229   1229  Astronomy & Astrophysics     1917
# 1230   1230  Astronomy & Astrophysics     1918
# 1231   1231  Astronomy & Astrophysics     1919
# 1232   1232  Astronomy & Astrophysics     1920
# 1233   1233  Astronomy & Astrophysics     1921
# 1234   1234  Astronomy & Astrophysics     1922
# 1235   1235  Astronomy & Astrophysics     1923
# 1236   1236  Astronomy & Astrophysics     1924
# 1237   1237  Astronomy & Astrophysics     1925
# 1238   1238  Astronomy & Astrophysics     1926
# 1239   1239  Astronomy & Astrophysics     1927
# 1240   1240  Astronomy & Astrophysics     1928
# 1241   1241  Astronomy & Astrophysics     1929
# ...     ...                       ...      ...
# 1299   1299  Astronomy & Astrophysics     1987
# 1300   1300  Astronomy & Astrophysics     1988
# 1301   1301  Astronomy & Astrophysics     1989
# 1302   1302  Astronomy & Astrophysics     1990
# 1303   1303  Astronomy & Astrophysics     1991
# 1304   1304  Astronomy & Astrophysics     1992
# 1305   1305  Astronomy & Astrophysics     1993
# 1306   1306  Astronomy & Astrophysics     1994
# 1307   1307  Astronomy & Astrophysics     1995
# 1308   1308  Astronomy & Astrophysics     1996
# 1309   1309  Astronomy & Astrophysics     1997
# 1310   1310  Astronomy & Astrophysics     1998
# 1311   1311  Astronomy & Astrophysics     1999
# 1312   1312  Astronomy & Astrophysics     2000
# 1313   1313  Astronomy & Astrophysics     2001
# 1314   1314  Astronomy & Astrophysics     2002
# 1315   1315  Astronomy & Astrophysics     2003
# 1316   1316  Astronomy & Astrophysics     2004
# 1317   1317  Astronomy & Astrophysics     2005
# 1318   1318  Astronomy & Astrophysics     2006
# 1319   1319  Astronomy & Astrophysics     2007
# 1320   1320  Astronomy & Astrophysics     2008
# 1321   1321  Astronomy & Astrophysics     2009
# 1322   1322  Astronomy & Astrophysics     2010
# 1323   1323  Astronomy & Astrophysics     2011
# 1324   1324  Astronomy & Astrophysics     2012
# 1325   1325  Astronomy & Astrophysics     2013
# 1326   1326  Astronomy & Astrophysics     2014
# 1327   1327  Astronomy & Astrophysics     2015
# 1328   1328  Astronomy & Astrophysics     2016
#
#                                 title_without_stopwords  \
# 1212  [crossley reflector lick obsertvatory, crossle...
# 1213  [accuracy photographic measures  second note ,...
# 1214  [miscellaneous results , miscellaneous results...
# 1215  [cape double star results  1903 , cape double ...
# 1216  [magnetic disturbances recorded royal observat...
# 1217  [note narrow triplets spectra calcium strontiu...
# 1218  [some notes lines motion calcium vapor, some n...
# 1219  [occultation hyades , occultation hyades , ven...
# 1220  [theory aberration , theory aberration , spect...
# 1221  [eight stars variable radial velocities, eight...
# 1222  [magnetic separation absorption lines connecti...
# 1223  [royal observatory  greenwich  observations no...
# 1224  [spectroscopic determination aqueous vapor, sp...
# 1225  [system photographic magnitudes southern stars...
# 1226  [influence local atmospheric cooling astronomi...
# 1227  [theory star streaming structure universe , th...
# 1228  [effect electric field lines calcium lithium, ...
# 1229  [effect longitudinal magnetic field upon glow ...
# 1230  [excess outward motion stars class, excess out...
# 1231  [studies based colors magnitudes stellar clust...
# 1232  [magnitudes nova cygni iii   1920  photographs...
# 1233  [solar motion radial velocities , solar motion...
# 1234  [investigation constancy wave length atmospher...
# 1235  [radiative  sic  rotating system  sic  musses ...
# 1236  [origin solar system  relation professor eddin...
# 1237  [motions stars scattered cluster 225 , motions...
# 1238  [stellar equilibrium influence distribution en...
# 1239  [solar rotation einstein displacement derived ...
# 1240  [period spectroscopic binary tau 9  eridani, p...
# 1241  [monochromatic images orion nebula , monochrom...
# ...                                                 ...
# 1299  [spatial mass distribution low mass dust parti...
# 1300  [local spectra wave distribution functions, lo...
# 1301  [visibility function effect observed character...
# 1302  [regularized analytic evaluation vacuum polari...
# 1303  [composition laws beltrami liouville theories ...
# 1304  [critical behavior pseudoscalar yukawa model, ...
# 1305  [quark  gluon ghost anomalous dimensions 0 1 n...
# 1306  [super minisuperspace variables, super minisup...
# 1307  [low frequency fluctuations magnetosheath near...
# 1308  [spiral structure alpha angstrom images  trace...
# 1309  [associated particle flux magnetic field modul...
# 1310  [extrema mass  first black hole mechanics  sta...
# 1311  [bifurcation topological structure sunspot s e...
# 1312  [spectral rules spontaneously broken chiral sy...
# 1313  [detection new  low brightness supernova remna...
# 1314  [transition region blinkers quiet sun properti...
# 1315  [dust emissivity submm mm scuba simba observat...
# 1316  [alpha stable approach study p d  distribution...
# 1317  [structures class magnetized scale free discs,...
# 1318  [efficient analysis planet transit surveys, ef...
# 1319  [infrared properties submillimeter galaxies  c...
# 1320  [development celss experimental facility, deve...
# 1321  [layer characteristics unusual boreal winters,...
# 1322  [exclusive plus charmonium production e   e   ...
# 1323  [implications constrained supersymmetry combin...
# 1324  [vision giant planet interiors  impact double ...
# 1325  [accumulation mass accelerating self gravitati...
# 1326  [glory revealed disk integrated photometry ven...
# 1327  [hydrodynamic modeling interaction winds withi...
# 1328  [space warps ii  gravitational lens candidates...
#
#                                          cleaned_titles  \
# 1212  [calculation elliptic elements system cygni , ...
# 1213  [form interferometer , sixty four variable sta...
# 1214  [researches spectra metals  spectrum molybdenu...
# 1215  [spectrographic observations standard velocity...
# 1216  [ninth satellite saturn , revised elements cyg...
# 1217  [figure sun , list twelve stars whose radial v...
# 1218  [results solar observations princeton  1905 19...
# 1219  [observations satellite neptune  photographs t...
# 1220  [note franks  analysis colours magnitudes star...
# 1221  [solar outburst magnetic storm , halley s come...
# 1222  [collmation correcting lens, measures faint pr...
# 1223  [various scales color estimates, distribution ...
# 1224  [parallax nova lacertae 1910 , yerkes actinome...
# 1225  [radial velocity tauri, mean latitudes moon su...
# 1226  [observations transit mercury  november 6 7  r...
# 1227  [cataloyne radiant points shooting stars  1998...
# 1228  [third line spectrum oxygen , note possible at...
# 1229  [photo electric photometry, photographic effec...
# 1230  [some probably variable stars , variable star ...
# 1231  [notes disturbed sun spot area sun s eastern l...
# 1232  [observations comets  reid    pons  winnecke  ...
# 1233  [geometrical classification long period variab...
# 1234  [excitation enhanced spectra sodium potassium ...
# 1235  [extension fundamental infra red absorption ba...
# 1236  [method deducing approximately focal lengths m...
# 1237  [method correcting series parallax observation...
# 1238  [liquid stars  configurations stability  long ...
# 1239  [constants star streams groningen proper motio...
# 1240  [mechanics chromosphere , spectrum solar coron...
# 1241  [absorption spectrum near ultra violet, theory...
# ...                                                 ...
# 1299  [chiral hierarchies chiral perturbations techn...
# 1300  [gamma ray detectors  greater than 10 mev , ob...
# 1301  [, effects thermal plasma self absorbed synchr...
# 1302  [, size upper limit position maser cit 6, worm...
# 1303  [factorial correlators from pi p collisions ge...
# 1304  [semiinclusive rapidity distributions critical...
# 1305  [flow contaminated solar wind comet p grigg sk...
# 1306  [production with heavy quarks e e  colliders, ...
# 1307  [neutral atomic phases interstellar medium, su...
# 1308  [resonance characteristics dielectric disk res...
# 1309  [determination length coronal loops decay x ra...
# 1310  [, superconformal six dimensional theories sup...
# 1311  [, cr 51 sr 90 sources borexino tools neutrino...
# 1312  [auto parallel equation euler lagrange s equat...
# 1313  [structure motions radio scales 0 6 300 parsec...
# 1314  [cassini huygens mission saturnian system, cla...
# 1315  [vector mesons q q over barq q over bar system...
# 1316  [quark mass textures beta, measurements atmosp...
# 1317  [empirical values transport coefficients solar...
# 1318  [origins martian aurora observed spectroscopy ...
# 1319  [nmagic  fast parallel implementation chi 2  m...
# 1320  [horizontal internetwork magnetic field  numer...
# 1321  [f r  cosmology presence phantom fluid scalar ...
# 1322  [improved calibration relations determination ...
# 1323  [, precession herbig haro flow infrared, magne...
# 1324  [stacking catalogue sources wmap data, oscilla...
# 1325  [equilibrium models radially anisotropic spher...
# 1326  [ground level enhancement january solar energe...
# 1327  [signatures majorana dark matter t channel med...
# 1328  [, spacetimes weyl ricci type higher dimension...
#
#                                            title_words_  \
# 1212  calculation elliptic elements system cygni  ph...
# 1213  form interferometer  sixty four variable stars...
# 1214  researches spectra metals  spectrum molybdenum...
# 1215  spectrographic observations standard velocity ...
# 1216  ninth satellite saturn  revised elements cygni...
# 1217  figure sun  list twelve stars whose radial vel...
# 1218  results solar observations princeton  1905 190...
# 1219  observations satellite neptune  photographs ta...
# 1220  note franks  analysis colours magnitudes stars...
# 1221  solar outburst magnetic storm  halley s comet ...
# 1222  collmation correcting lens measures faint prop...
# 1223  various scales color estimates distribution br...
# 1224  parallax nova lacertae 1910  yerkes actinometr...
# 1225  radial velocity tauri mean latitudes moon sun ...
# 1226  observations transit mercury  november 6 7  ro...
# 1227  cataloyne radiant points shooting stars  1998 ...
# 1228  third line spectrum oxygen  note possible attr...
# 1229  photo electric photometry photographic effecti...
# 1230  some probably variable stars  variable star ur...
# 1231  notes disturbed sun spot area sun s eastern li...
# 1232  observations comets  reid    pons  winnecke   ...
# 1233  geometrical classification long period variabl...
# 1234  excitation enhanced spectra sodium potassium v...
# 1235  extension fundamental infra red absorption ban...
# 1236  method deducing approximately focal lengths ma...
# 1237  method correcting series parallax observations...
# 1238  liquid stars  configurations stability  long p...
# 1239  constants star streams groningen proper motion...
# 1240  mechanics chromosphere  spectrum solar corona ...
# 1241  absorption spectrum near ultra violet theory m...
# ...                                                 ...
# 1299  chiral hierarchies chiral perturbations techni...
# 1300  gamma ray detectors  greater than 10 mev  obse...
# 1301   effects thermal plasma self absorbed synchrot...
# 1302   size upper limit position maser cit 6 wormhol...
# 1303  factorial correlators from pi p collisions gev...
# 1304  semiinclusive rapidity distributions critical ...
# 1305  flow contaminated solar wind comet p grigg skj...
# 1306  production with heavy quarks e e  colliders an...
# 1307  neutral atomic phases interstellar medium sum ...
# 1308  resonance characteristics dielectric disk reso...
# 1309  determination length coronal loops decay x ray...
# 1310   superconformal six dimensional theories super...
# 1311   cr 51 sr 90 sources borexino tools neutrino m...
# 1312  auto parallel equation euler lagrange s equati...
# 1313  structure motions radio scales 0 6 300 parsecs...
# 1314  cassini huygens mission saturnian system class...
# 1315  vector mesons q q over barq q over bar systems...
# 1316  quark mass textures beta measurements atmosphe...
# 1317  empirical values transport coefficients solar ...
# 1318  origins martian aurora observed spectroscopy i...
# 1319  nmagic  fast parallel implementation chi 2  ma...
# 1320  horizontal internetwork magnetic field  numeri...
# 1321  f r  cosmology presence phantom fluid scalar t...
# 1322  improved calibration relations determination e...
# 1323   precession herbig haro flow infrared magnetic...
# 1324  stacking catalogue sources wmap data oscillati...
# 1325  equilibrium models radially anisotropic spheri...
# 1326  ground level enhancement january solar energet...
# 1327  signatures majorana dark matter t channel medi...
# 1328   spacetimes weyl ricci type higher dimensions ...
#
#                                             title_words  number_of_pubs  \
# 1212  calculation elliptic elements system cygni phy...             356
# 1213  form interferometer sixty four variable stars ...             296
# 1214  researches spectra metals spectrum molybdenum ...             304
# 1215  spectrographic observations standard velocity ...             330
# 1216  ninth satellite saturn revised elements cygni ...             348
# 1217  figure sun list twelve stars whose radial velo...             288
# 1218  results solar observations princeton observati...             340
# 1219  observations satellite neptune photographs tak...             348
# 1220  note franks analysis colours magnitudes stars ...             324
# 1221  solar outburst magnetic storm halley s comet o...             288
# 1222  collmation correcting lens measures faint prop...             266
# 1223  various scales color estimates distribution br...             260
# 1224  parallax nova lacertae yerkes actinometry zone...             242
# 1225  radial velocity tauri mean latitudes moon sun ...             238
# 1226  observations transit mercury november royal ob...             314
# 1227  cataloyne radiant points shooting stars measur...             264
# 1228  third line spectrum oxygen note possible attra...             264
# 1229  photo electric photometry photographic effecti...             282
# 1230  some probably variable stars variable star urs...             262
# 1231  notes disturbed sun spot area sun s eastern li...             290
# 1232  observations comets reid pons winnecke dubaago...             258
# 1233  geometrical classification long period variabl...             270
# 1234  excitation enhanced spectra sodium potassium v...             226
# 1235  extension fundamental infra red absorption ban...             270
# 1236  method deducing approximately focal lengths ma...             332
# 1237  method correcting series parallax observations...             232
# 1238  liquid stars configurations stability long per...             236
# 1239  constants star streams groningen proper motion...             246
# 1240  mechanics chromosphere spectrum solar corona p...             246
# 1241  absorption spectrum near ultra violet theory m...             244
# ...                                                 ...             ...
# 1299  chiral hierarchies chiral perturbations techni...           19864
# 1300  gamma ray detectors greater than mev observati...           18376
# 1301  effects thermal plasma self absorbed synchrotr...           18910
# 1302  size upper limit position maser cit wormhole s...           20090
# 1303  factorial correlators from pi p collisions gev...           19898
# 1304  semiinclusive rapidity distributions critical ...           19958
# 1305  flow contaminated solar wind comet p grigg skj...           21970
# 1306  production with heavy quarks e e colliders ano...           21944
# 1307  neutral atomic phases interstellar medium sum ...           22114
# 1308  resonance characteristics dielectric disk reso...           22458
# 1309  determination length coronal loops decay x ray...           23010
# 1310  superconformal six dimensional theories supers...           24224
# 1311  cr sr sources borexino tools neutrino magnetic...           23822
# 1312  auto parallel equation euler lagrange s equati...           24274
# 1313  structure motions radio scales parsecs where u...           25904
# 1314  cassini huygens mission saturnian system class...           25276
# 1315  vector mesons q q over barq q over bar systems...           26076
# 1316  quark mass textures beta measurements atmosphe...           26624
# 1317  empirical values transport coefficients solar ...           26684
# 1318  origins martian aurora observed spectroscopy i...           29222
# 1319  nmagic fast parallel implementation chi made t...           29468
# 1320  horizontal internetwork magnetic field numeric...           31534
# 1321  f r cosmology presence phantom fluid scalar te...           33334
# 1322  improved calibration relations determination e...           33470
# 1323  precession herbig haro flow infrared magnetic ...           36158
# 1324  stacking catalogue sources wmap data oscillati...           37606
# 1325  equilibrium models radially anisotropic spheri...           37184
# 1326  ground level enhancement january solar energet...           38132
# 1327  signatures majorana dark matter t channel medi...           39652
# 1328  spacetimes weyl ricci type higher dimensions f...           36936
#
#       word_count
# 1212        1040
# 1213         843
# 1214         950
# 1215         990
# 1216         985
# 1217         750
# 1218         940
# 1219        1080
# 1220         959
# 1221         887
# 1222         838
# 1223         717
# 1224         730
# 1225         677
# 1226         908
# 1227         778
# 1228         790
# 1229         779
# 1230         726
# 1231         857
# 1232         806
# 1233         762
# 1234         685
# 1235         790
# 1236         997
# 1237         624
# 1238         656
# 1239         677
# 1240         663
# 1241         628
# ...          ...
# 1299       68977
# 1300       64335
# 1301       66708
# 1302       70362
# 1303       70450
# 1304       71284
# 1305       80603
# 1306       81197
# 1307       82225
# 1308       79419
# 1309       81930
# 1310       87165
# 1311       85876
# 1312       88160
# 1313       94591
# 1314       94075
# 1315       96649
# 1316       99929
# 1317      101118
# 1318      112155
# 1319      114931
# 1320      121928
# 1321      132599
# 1322      134555
# 1323      146563
# 1324      154235
# 1325      153387
# 1326      157002
# 1327      163850
# 1328      153669
#
# [117 rows x 9 columns]

# %%
#word_ = "Dextromoramide"

#word_ = "purposed"
#word_ = "quayside"


#word_ = "chiaroscuro"
# word_ = "solothurn" -name of a city
#word_ = "neurotropism" - biology to virology
#word_ = "glycylproline"
#word_ = "burnie"
#word_ = "baikalensis"

#-------------------------------------------------------- These words appear in less number of disciplines ----------------------------------#
#word_ = "bepposax"
#word_ = "aglykone"

#------------------------ many words appearing in bottom part of the curve at the left top are astrophysics related words ---------------------#
#word_ = "rxte"

#----------- others ----------------#
word_ = "amee"

index = words.index(word_)
count_rev_dict[index]
counts = vectorized_wordarray[:,index]

discipline_indices = [discipline_index for discipline_index in range(len(counts.tolist())) if counts[discipline_index] != 0]

counts_for_disciplines = {discipline_index: count for discipline_index, count in enumerate(counts.tolist())}
sorted_counts = sorted(counts_for_disciplines.items(), key=operator.itemgetter(1), reverse=True)

total_disciplines_present = len([count for i, count in enumerate(counts.tolist()) if count > 0])
to_show_count = 5

top_5_disciplines = [index for (index, count) in sorted_counts[:5]]
if total_disciplines_present < 5:
    top_5_disciplines = [index for (index, count) in sorted_counts[:total_disciplines_present]]
     
#disciplines = [list(tovector_input.index)[index] for index in discipline_indices]
disciplines = tovector_input.reset_index()["Label"]
present_dis = [disciplines[i] for i in top_5_disciplines]
print("Total disciplines present",len([count for i, count in enumerate(counts.tolist()) if count > 0]))
print("Present in:", present_dis)
print("Count:", len(disciplines))
# Out:
# Total disciplines present 3
# Present in: ['Education & Educational Research', 'Education, Scientific Disciplines', 'Health Care Sciences & Services']
# Count: 249

# %%
def word_counts2(discipline, word):

    _data = data_grouped_by_year_label[data_grouped_by_year_label.Label == discipline]
    
    _data["selected_word_count"] = _data["title_words"].apply(lambda x: x.split().count(word))
    _data["normalized_selected_word_count"] = _data.apply(lambda x: float(x["selected_word_count"])/x["number_of_pubs"], axis=1) 
    
    return _data["PubYear"].tolist(), _data["normalized_selected_word_count"].tolist(), _data["selected_word_count"].tolist(), _data["number_of_pubs"].tolist()

# %%
years = []
freqs = []
papers = []
wcs = []

for dis in present_dis:
    
    _ys, _fqs, _wcs, _papers = word_counts2(dis, word_)
    
    years.append(_ys)
    freqs.append(_fqs)
    wcs.append(_wcs)
    papers.append(_papers)

# %%
datatoplot = [go.Scatter(
            x=years[0],
            y=freqs[0],
            mode = 'lines+markers',
            text = list(map(str, wcs[0])),
            name=present_dis[0],
    ),go.Scatter(
            x=years[1],
            y=freqs[1],
            mode='lines',
            text = list(map(str, wcs[1])),
            name=present_dis[1],
    ),go.Scatter(
            x=years[2],
            y=freqs[2],
            mode='lines',
            text = list(map(str, wcs[2])),
            name=present_dis[2],
#     ),go.Scatter(
#             x=years[3],
#             y=freqs[3],
#             mode='lines',
#             text = papers[3],
#             name=present_dis[3],
#     ),go.Scatter(
#             x=years[4],
#             y=freqs[4],
#             mode='lines',
#             text = papers[4],
#             name=present_dis[4]
    )]




layout = go.Layout(
    title='Word Propagation ' + word_,
    
    xaxis=dict(
        title='Year',
        titlefont=dict(
            family='Lato',
            color='#7f7f7f'
        )
    ),
    yaxis=dict(
        title='Popularity Ratio',
        titlefont=dict(
            family='Lato',
            color='#7f7f7f'
        )
    )
)


fig1 = go.Figure(data=datatoplot, layout=layout)
py.iplot(fig1, filename='freq')
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~sreejith_s/320.embed" height="525px" width="100%"></iframe>
